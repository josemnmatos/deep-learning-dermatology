# %%
from custom_models.cnn import CNN
from helper_methods import get_data_loaders
from pipeline import CustomModelPipeline
from torch import optim
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import torch
import pandas as pd


# set seaborn style
sns.set_theme(
    context="notebook", style="whitegrid", palette="bright", color_codes=True, rc=None
)

# %%
# Experiment repetitions
N_REPEATS = 5

# Training config
N_EPOCHS = 50
DATA_AUG_TRAIN = True

#Model Hyperparameters
LOSS_FN = nn.CrossEntropyLoss()
OPTIMIZER_CLASS = optim.Adam
LR = 0.0005

# Early Stopping Configuration
ES_PATIENCE = 10
MIN_ES_DELTA = 0.001

# %%
def init_pipeline(
    train_loader,
    validation_loader,
    train_loader_at_eval,
    test_loader,
    input_size,
    num_classes,
    patience=ES_PATIENCE,  # Add patience parameter
):
    """Initialize pipeline with MLP model"""
    # Initialize MLP with proper parameters
    model = CNN()

    pipeline = CustomModelPipeline(
        model=model,
        criterion=LOSS_FN,
        min_delta=MIN_ES_DELTA,
        optimizer_class=OPTIMIZER_CLASS,
        optimizer_params={
            "lr": LR,
        },
        n_epochs=N_EPOCHS,
        training_data=train_loader,
        validation_data=validation_loader,
        test_data=test_loader,
        patience=patience,  # Pass patience parameter
        device="cuda" if torch.cuda.is_available() else "cpu",
    )
    return pipeline


(
    train_loader,
    train_loader_at_eval,
    test_loader,
    validation_loader,
    n_channels,
    n_classes,
    task,
    pil_dataset,
) = get_data_loaders(data_augmentation=True)

# first sample
sample = next(iter(train_loader))
print(f"Sample Shape: {sample[0].shape}")

# No of Neurons in Input Layer
# Output is flattened before feeding to MLP
input_size = n_channels * sample[0].shape[2] * sample[0].shape[3]

# No of Neurons in Output Layer
num_classes = n_classes

print(f"Input size: {input_size}, Number of classes: {num_classes}")

accuracies = []
f1_scores = []
t_losses = []
v_losses = []
t_durations = []

# Create and execute pipelines for each repeat
for i in range(N_REPEATS):
    print(f"Repeat {i + 1}/{N_REPEATS}")
    pipeline = init_pipeline(
        train_loader,
        validation_loader,
        train_loader_at_eval,
        test_loader,
        input_size,
        num_classes,
    )
    pipeline.execute_and_validate()
    # get scores on test data
    scores = pipeline.get_validation_scores()
    accuracies.append(scores["accuracy"])
    f1_scores.append(scores["f1"])

    losses = pipeline.get_losses()
    t_losses.append(losses["train"])
    v_losses.append(losses["val"])

    t_durations.append(pipeline.get_run_duration())
# Out:
# MedMNIST v3.0.2 @ https://github.com/MedMNIST/MedMNIST/
# Using downloaded and verified file: C:\Users\josem\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\josem\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\josem\.medmnist\dermamnist.npz
# Using downloaded and verified file: C:\Users\josem\.medmnist\dermamnist.npz
# --------------------------------------------------
# Applied Training Augmentations:
# - ToTensor()
# - RandomHorizontalFlip(p=0.5)
# - RandomVerticalFlip(p=0.5)
# - RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
# --------------------------------------------------
# tensor([ 4.3904,  2.7883,  1.3017, 12.5125,  1.2850,  0.2133, 10.1111],
#        device='cuda:0')
# Sample Shape: torch.Size([128, 3, 28, 28])
# Input size: 2352, Number of classes: 7
# Repeat 1/5
# Using device: cuda
# Starting training for 50 epochs...
# Epoch 1/50 - Train Loss: 0.9971, Val Loss: 1.6466
# Epoch 2/50 - Train Loss: 0.8481, Val Loss: 0.8542
# Epoch 3/50 - Train Loss: 0.8089, Val Loss: 0.7542
# Epoch 4/50 - Train Loss: 0.7725, Val Loss: 0.7517
# Epoch 5/50 - Train Loss: 0.7527, Val Loss: 0.7277
# Epoch 24/50 - Train Loss: 0.5744, Val Loss: 0.7126
# Epoch 25/50 - Train Loss: 0.5808, Val Loss: 0.6888
# Epoch 26/50 - Train Loss: 0.5741, Val Loss: 0.6466
# Epoch 27/50 - Train Loss: 0.5647, Val Loss: 1.0209
# Epoch 28/50 - Train Loss: 0.5509, Val Loss: 0.6353
# Epoch 29/50 - Train Loss: 0.5531, Val Loss: 0.7932
# Epoch 30/50 - Train Loss: 0.5467, Val Loss: 0.6869
# Epoch 31/50 - Train Loss: 0.5372, Val Loss: 0.7508
# Epoch 32/50 - Train Loss: 0.5296, Val Loss: 0.6840
# Epoch 33/50 - Train Loss: 0.5313, Val Loss: 0.6326
# Epoch 34/50 - Train Loss: 0.5256, Val Loss: 0.6604
# Epoch 35/50 - Train Loss: 0.5165, Val Loss: 0.6609
# Epoch 36/50 - Train Loss: 0.5068, Val Loss: 0.7236
# Epoch 37/50 - Train Loss: 0.5035, Val Loss: 0.6921
# Epoch 38/50 - Train Loss: 0.4909, Val Loss: 0.6760
# Epoch 39/50 - Train Loss: 0.4933, Val Loss: 0.6982
# Epoch 40/50 - Train Loss: 0.4911, Val Loss: 0.6476
# Epoch 41/50 - Train Loss: 0.4744, Val Loss: 0.6897
# Epoch 42/50 - Train Loss: 0.4679, Val Loss: 0.7163
# Epoch 43/50 - Train Loss: 0.4647, Val Loss: 0.7785
# Early stopping triggered at epoch 43.
# Loaded best model state based on validation loss.
# Training completed in 319.52 seconds.
# Evaluating best model on VALIDATION set...
# Validation Accuracy: 0.7797
# Validation Macro F1 Score: 0.5027
# Repeat 3/5
# Using device: cuda
# Starting training for 50 epochs...
# Epoch 1/50 - Train Loss: 0.9881, Val Loss: 1.8475
# Epoch 2/50 - Train Loss: 0.8487, Val Loss: 0.8978
# Epoch 3/50 - Train Loss: 0.8041, Val Loss: 0.7407
# Epoch 4/50 - Train Loss: 0.7621, Val Loss: 0.7159
# Epoch 5/50 - Train Loss: 0.7490, Val Loss: 0.7246
# Epoch 6/50 - Train Loss: 0.7235, Val Loss: 0.7786
# Epoch 7/50 - Train Loss: 0.7016, Val Loss: 0.6896
# Epoch 8/50 - Train Loss: 0.7001, Val Loss: 0.6674
# Epoch 9/50 - Train Loss: 0.6856, Val Loss: 0.6889
# Epoch 10/50 - Train Loss: 0.6708, Val Loss: 0.7516
# Epoch 11/50 - Train Loss: 0.6728, Val Loss: 0.6756
# Epoch 12/50 - Train Loss: 0.6644, Val Loss: 0.6608
# Epoch 13/50 - Train Loss: 0.6496, Val Loss: 0.6577
# Epoch 14/50 - Train Loss: 0.6459, Val Loss: 0.6576
# Epoch 15/50 - Train Loss: 0.6394, Val Loss: 0.6507
# Epoch 16/50 - Train Loss: 0.6316, Val Loss: 0.6667
# Epoch 17/50 - Train Loss: 0.6190, Val Loss: 0.6519
# Epoch 18/50 - Train Loss: 0.6166, Val Loss: 0.6761
# Epoch 19/50 - Train Loss: 0.6183, Val Loss: 0.7344
# Epoch 20/50 - Train Loss: 0.6025, Val Loss: 0.6501
# Epoch 21/50 - Train Loss: 0.5966, Val Loss: 0.7009
# Epoch 22/50 - Train Loss: 0.5946, Val Loss: 0.6473
# Epoch 23/50 - Train Loss: 0.5819, Val Loss: 0.6279
# Epoch 24/50 - Train Loss: 0.5803, Val Loss: 0.6676
# Epoch 25/50 - Train Loss: 0.5739, Val Loss: 0.6740
# Epoch 26/50 - Train Loss: 0.5740, Val Loss: 0.7885
# Epoch 27/50 - Train Loss: 0.5542, Val Loss: 0.6525
# Epoch 28/50 - Train Loss: 0.5484, Val Loss: 0.7406
# Epoch 29/50 - Train Loss: 0.5562, Val Loss: 0.7152
# Epoch 30/50 - Train Loss: 0.5486, Val Loss: 0.6654
# Epoch 31/50 - Train Loss: 0.5310, Val Loss: 0.6433
# Epoch 32/50 - Train Loss: 0.5269, Val Loss: 0.8432
# Epoch 33/50 - Train Loss: 0.5273, Val Loss: 0.6656
# Early stopping triggered at epoch 33.
# Loaded best model state based on validation loss.
# Training completed in 244.78 seconds.
# Evaluating best model on VALIDATION set...
# Validation Accuracy: 0.7667
# Validation Macro F1 Score: 0.4870
# Repeat 4/5
# Using device: cuda
# Starting training for 50 epochs...
# Epoch 1/50 - Train Loss: 0.9883, Val Loss: 1.6743
# Epoch 2/50 - Train Loss: 0.8443, Val Loss: 0.9057
# Epoch 3/50 - Train Loss: 0.8066, Val Loss: 0.7825
# Epoch 4/50 - Train Loss: 0.7778, Val Loss: 0.7591
# Epoch 5/50 - Train Loss: 0.7398, Val Loss: 0.7120
# Epoch 6/50 - Train Loss: 0.7352, Val Loss: 0.7642
# Epoch 7/50 - Train Loss: 0.7192, Val Loss: 0.6984
# Epoch 8/50 - Train Loss: 0.6937, Val Loss: 0.7022
# Epoch 9/50 - Train Loss: 0.6921, Val Loss: 0.6765
# Epoch 10/50 - Train Loss: 0.6802, Val Loss: 0.7133
# Epoch 11/50 - Train Loss: 0.6689, Val Loss: 0.6818
# Epoch 12/50 - Train Loss: 0.6624, Val Loss: 0.7113
# Epoch 13/50 - Train Loss: 0.6412, Val Loss: 0.6670
# Epoch 14/50 - Train Loss: 0.6497, Val Loss: 0.7261
# Epoch 15/50 - Train Loss: 0.6361, Val Loss: 0.6675
# Epoch 16/50 - Train Loss: 0.6362, Val Loss: 0.6592
# Epoch 17/50 - Train Loss: 0.6319, Val Loss: 0.6412
# Epoch 18/50 - Train Loss: 0.6164, Val Loss: 0.6622
# Epoch 19/50 - Train Loss: 0.5984, Val Loss: 0.6448
# Epoch 20/50 - Train Loss: 0.6052, Val Loss: 0.6415
# Epoch 21/50 - Train Loss: 0.5918, Val Loss: 0.6743
# Epoch 22/50 - Train Loss: 0.5979, Val Loss: 0.6481
# Epoch 23/50 - Train Loss: 0.5805, Val Loss: 0.6711
# Epoch 24/50 - Train Loss: 0.5783, Val Loss: 0.6517
# Epoch 25/50 - Train Loss: 0.5809, Val Loss: 0.7295
# Epoch 26/50 - Train Loss: 0.5642, Val Loss: 0.8862
# Epoch 27/50 - Train Loss: 0.5629, Val Loss: 0.6646
# Early stopping triggered at epoch 27.
# Loaded best model state based on validation loss.
# Training completed in 200.39 seconds.
# Evaluating best model on VALIDATION set...
# Validation Accuracy: 0.7577
# Validation Macro F1 Score: 0.4572
# Repeat 5/5
# Using device: cuda
# Starting training for 50 epochs...
# Epoch 1/50 - Train Loss: 0.9901, Val Loss: 1.6464
# Epoch 2/50 - Train Loss: 0.8493, Val Loss: 0.8149
# Epoch 3/50 - Train Loss: 0.8047, Val Loss: 0.7334
# Epoch 4/50 - Train Loss: 0.7685, Val Loss: 0.7544
# Epoch 5/50 - Train Loss: 0.7419, Val Loss: 0.7933
# Epoch 6/50 - Train Loss: 0.7224, Val Loss: 0.7491
# Epoch 7/50 - Train Loss: 0.7055, Val Loss: 0.6865
# Epoch 8/50 - Train Loss: 0.6941, Val Loss: 0.8509
# Epoch 9/50 - Train Loss: 0.6900, Val Loss: 0.6682
# Epoch 10/50 - Train Loss: 0.6820, Val Loss: 0.7250
# Epoch 11/50 - Train Loss: 0.6740, Val Loss: 0.6774
# Epoch 12/50 - Train Loss: 0.6596, Val Loss: 0.7193
# Epoch 13/50 - Train Loss: 0.6529, Val Loss: 0.6925
# Epoch 14/50 - Train Loss: 0.6457, Val Loss: 0.7166
# Epoch 15/50 - Train Loss: 0.6341, Val Loss: 0.6828
# Epoch 16/50 - Train Loss: 0.6296, Val Loss: 0.6837
# Epoch 17/50 - Train Loss: 0.6428, Val Loss: 0.6434
# Epoch 18/50 - Train Loss: 0.6190, Val Loss: 0.8035
# Epoch 19/50 - Train Loss: 0.6129, Val Loss: 0.6404
# Epoch 20/50 - Train Loss: 0.6009, Val Loss: 0.7107
# Epoch 21/50 - Train Loss: 0.5952, Val Loss: 0.6662
# Epoch 22/50 - Train Loss: 0.5940, Val Loss: 0.6729
# Epoch 23/50 - Train Loss: 0.5879, Val Loss: 0.6871
# Epoch 24/50 - Train Loss: 0.5923, Val Loss: 0.6577
# Epoch 25/50 - Train Loss: 0.5756, Val Loss: 0.7211
# Epoch 26/50 - Train Loss: 0.5617, Val Loss: 0.6829
# Epoch 27/50 - Train Loss: 0.5561, Val Loss: 0.6476
# Epoch 28/50 - Train Loss: 0.5530, Val Loss: 0.6535
# Epoch 29/50 - Train Loss: 0.5448, Val Loss: 0.9000
# Early stopping triggered at epoch 29.
# Loaded best model state based on validation loss.
# Training completed in 214.65 seconds.
# Evaluating best model on VALIDATION set...
# Validation Accuracy: 0.7468
# Validation Macro F1 Score: 0.4529

# %%
# From: https://stackoverflow.com/a/15034143
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

mci_accuracy = mean_confidence_interval(accuracies)
mci_f1 = mean_confidence_interval(f1_scores)
mci_training_duration = mean_confidence_interval(t_durations)

# Mean +- CI
print(f"Accuracy: {mci_accuracy[0]:.4f} +- {(mci_accuracy[2] - mci_accuracy[0]):.4f}")
print(f"({mci_accuracy[1]:.4f}, {mci_accuracy[2]:.4f})")
print(f"F1 Score: {mci_f1[0]:.4f} +- {(mci_f1[2] - mci_f1[0]):.4f}")
print(f"({mci_f1[1]:.4f}, {mci_f1[2]:.4f})")
print(f"Training Duration: {mci_training_duration[0]:.4f} +- {(mci_training_duration[2] - mci_training_duration[0]):.4f}")
print(f"({mci_training_duration[1]:.4f}, {mci_training_duration[2]:.4f})")
# Out:
# Accuracy: 0.7617 +- 0.0152
# (0.7465, 0.7770)
# F1 Score: 0.4707 +- 0.0282
# (0.4425, 0.4990)
# Training Duration: 234.8696 +- 63.4641
# (171.4055, 298.3337)

# %%
from helper_methods import plot_avg_losses

plot_avg_losses(t_losses, v_losses)
